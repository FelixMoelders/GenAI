# %% [markdown]
# # 🔧 LoRA Training (Stable Diffusion XL (SDXL)) — Google Colab
#
# ---

# %% [markdown]
# ## Step 1 : Dependency Installation

# %%
# !pip install \
  opencv-python \
  diffusers["torch"] \
  transformers \
  accelerate \
  safetensors \
  tensorboard \
  einops \
  torchaudio \
  xformers \
  bitsandbytes \
  prodigyopt \
  lion-pytorch \
  opencv-python \
  ftfy \
  easygui \
  toml \
  voluptuous \
  imagesize \
  peft

# !pip install --force-reinstall --no-cache-dir \
  torch==2.9.1 \
  torchvision \
  torchaudio==2.9.1
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.12/site-packages (4.57.1)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.12/site-packages (1.11.0)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.12/site-packages (2.18.0)
# Collecting einops
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting xformers
#   Downloading xformers-0.0.33.post2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting prodigyopt
#   Downloading prodigyopt-1.1.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting lion-pytorch
#   Downloading lion_pytorch-0.2.3-py3-none-any.whl.metadata (616 bytes)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting easygui
#   Downloading easygui-0.98.3-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting voluptuous
#   Downloading voluptuous-0.16.0-py3-none-any.whl.metadata (20 kB)
# Collecting imagesize
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting peft
#   Downloading peft-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: diffusers[torch] in /opt/conda/lib/python3.12/site-packages (0.36.0)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (6.10.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (3.20.0)
# Requirement already satisfied: httpx<1.0.0 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (2025.11.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (2.32.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (11.3.0)
# Requirement already satisfied: torch>=1.4 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (2.6.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (4.11.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->diffusers[torch]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.15.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/conda/lib/python3.12/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (1.67.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (3.10)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.12/site-packages (from tensorboard) (5.28.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (80.9.0)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from tensorboard) (3.1.3)
# Collecting torch>=1.4 (from diffusers[torch])
#   Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (3.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch>=1.4->diffusers[torch])
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch>=1.4->diffusers[torch])
#   Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from ftfy) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.4->diffusers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<1.0.0->diffusers[torch]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib_metadata->diffusers[torch]) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->diffusers[torch]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->diffusers[torch]) (1.26.20)
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 164.9 MB/s  0:00:00m0:00:0100:01
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 174.8 MB/s  0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 141.7 MB/s  0:00:00
# Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 36.7 MB/s  0:00:09m0:00:0100:01
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 49.4 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 165.3 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 161.6 MB/s  0:00:00m0:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 100.9 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 46.2 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 128.7 MB/s  0:00:010:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 99.6 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 148.1 MB/s  0:00:00m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 102.9 MB/s  0:00:020:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 95.0 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 102.7 MB/s  0:00:020:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 96.5 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 169.6 MB/s  0:00:00m0:00:01
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 131.8 MB/s  0:00:000:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 131.6 MB/s  0:00:010:00:0100:01
# Downloading xformers-0.0.33.post2-cp39-abi3-manylinux_2_28_x86_64.whl (122.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 123.0 MB/s  0:00:010:00:0100:01
# Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 164.5 MB/s  0:00:00 eta 0:00:01
# Downloading prodigyopt-1.1.2-py3-none-any.whl (10 kB)
# Downloading lion_pytorch-0.2.3-py3-none-any.whl (6.6 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Downloading easygui-0.98.3-py2.py3-none-any.whl (92 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading voluptuous-0.16.0-py3-none-any.whl (31 kB)
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading peft-0.18.0-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 556.4/556.4 kB 52.1 MB/s  0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, easygui, voluptuous, triton, toml, prodigyopt, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, imagesize, ftfy, einops, opencv-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, xformers, torchaudio, lion-pytorch, bitsandbytes, peft
#   Attempting uninstall: triton━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/31 [voluptuous]
#     Found existing installation: triton 3.2.0+git576374f8━━━━━  2/31 [voluptuous]
#     Uninstalling triton-3.2.0+git576374f8:━━━━━━━━━━━━━━━━━━━━  2/31 [voluptuous]
#       Successfully uninstalled triton-3.2.0+git576374f8━━━━━━━  2/31 [voluptuous]
#   Attempting uninstall: numpy0m╺━━━━━━━━━━━━━━━━━━━━ 15/31 [nvidia-cublas-cu12]u12]
#     Found existing installation: numpy 1.26.4━━━━━━━━━━━━━━━━━ 15/31 [nvidia-cublas-cu12]
#     Uninstalling numpy-1.26.4:0m╸━━━━━━━━━━━━━━━━━━━ 16/31 [numpy]las-cu12]
#       Successfully uninstalled numpy-1.26.4━━━━━━━━━━━━━━━━━━━ 16/31 [numpy]
#   Attempting uninstall: torch━━━━━━━━━╸━━━━━━━━━ 24/31 [nvidia-cusolver-cu12]
#     Found existing installation: torch 2.6.0━━━━━━━━━ 24/31 [nvidia-cusolver-cu12]
#     Uninstalling torch-2.6.0:━━━━━━━━━━━╺━━━━━━━ 25/31 [torch]olver-cu12]
#       Successfully uninstalled torch-2.6.090m╺━━━━━━━ 25/31 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31/31 [peft]2m30/31 [peft]ndbytes]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.8 requires onnxruntime<2,>=1.15.0, which is not installed.
# autogluon-multimodal 1.4.0 requires nvidia-ml-py3<8.0,>=7.352.0, which is not installed.
# sagemaker-studio 1.1.1 requires pydynamodb>=0.7.4, which is not installed.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.8 requires numpy<=2.0.1, but you have numpy 2.2.6 which is incompatible.
# amazon-sagemaker-sql-magic 0.1.4 requires numpy<2, but you have numpy 2.2.6 which is incompatible.
# autogluon-multimodal 1.4.0 requires torch<2.8,>=2.2, but you have torch 2.9.1 which is incompatible.
# autogluon-multimodal 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.57.1 which is incompatible.
# autogluon-timeseries 1.4.0 requires torch<2.8,>=2.2, but you have torch 2.9.1 which is incompatible.
# autogluon-timeseries 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.57.1 which is incompatible.
# gluonts 0.16.2 requires numpy<2.2,>=1.16, but you have numpy 2.2.6 which is incompatible.
# langchain-aws 0.2.19 requires boto3>=1.37.24, but you have boto3 1.37.3 which is incompatible.
# sagemaker 2.245.0 requires numpy==1.26.4, but you have numpy 2.2.6 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.3.3 which is incompatible.
# Successfully installed bitsandbytes-0.49.0 easygui-0.98.3 einops-0.8.1 ftfy-6.3.1 imagesize-1.4.1 lion-pytorch-0.2.3 numpy-2.2.6 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 opencv-python-4.12.0.88 peft-0.18.0 prodigyopt-1.1.2 toml-0.10.2 torch-2.9.1 torchaudio-2.9.1 triton-3.5.1 voluptuous-0.16.0 xformers-0.0.33.post2
# Collecting torch==2.9.1
#   Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision
#   Downloading torchvision-0.24.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting torchaudio==2.9.1
#   Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting filelock (from torch==2.9.1)
#   Downloading filelock-3.20.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting typing-extensions>=4.10.0 (from torch==2.9.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting setuptools (from torch==2.9.1)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch==2.9.1)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch==2.9.1)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch==2.9.1)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch==2.9.1)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch==2.9.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch==2.9.1)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch==2.9.1)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.9.1)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch==2.9.1)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch==2.9.1)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch==2.9.1)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch==2.9.1)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch==2.9.1)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch==2.9.1)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch==2.9.1)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch==2.9.1)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch==2.9.1)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch==2.9.1)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch==2.9.1)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch==2.9.1)
#   Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting numpy (from torchvision)
#   Downloading numpy-2.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch==2.9.1)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.9.1)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 307.5 MB/s  0:00:02eta 0:00:01
# Downloading torchaudio-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 630.1 MB/s  0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 285.6 MB/s  0:00:02eta 0:00:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 224.0 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 232.4 MB/s  0:00:00 eta 0:00:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 375.5 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 265.2 MB/s  0:00:02eta 0:00:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 275.4 MB/s  0:00:00eta 0:00:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 584.7 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 335.8 MB/s  0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 310.8 MB/s  0:00:00eta 0:00:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 226.2 MB/s  0:00:01eta 0:00:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 264.4 MB/s  0:00:01eta 0:00:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 296.7 MB/s  0:00:01eta 0:00:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 319.3 MB/s  0:00:00
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 294.3 MB/s  0:00:00eta 0:00:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 280.8 MB/s  0:00:000:00:0100:01
# Downloading torchvision-0.24.1-cp312-cp312-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 363.6 MB/s  0:00:00
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 474.5 MB/s  0:00:00
# Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 280.8 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 194.1 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 505.4 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading filelock-3.20.2-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading numpy-2.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 191.9 MB/s  0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 545.2 MB/s  0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, triton, sympy, setuptools, pillow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: mpmath━━━━━━━━━━━━━━━━━━  0/30 [nvidia-cusparselt-cu12]
#     Found existing installation: mpmath 1.3.0━━━━━━━━━━━━━━━━━━━━━  1/30 [mpmath]
#     Uninstalling mpmath-1.3.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/30 [mpmath]
#       Successfully uninstalled mpmath-1.3.0━━━━━━━━━━━━━━━━━━━  1/30 [mpmath]
#   Attempting uninstall: typing-extensions━━━━━━━━━━━━━━━━━━━━━━━━━  1/30 [mpmath]
#     Found existing installation: typing_extensions 4.15.0━━━━━  1/30 [mpmath]
#     Uninstalling typing_extensions-4.15.0:━━━━━━━━━━━━━━━━━━━━  1/30 [mpmath]
#       Successfully uninstalled typing_extensions-4.15.0━━━━━━━━━━━  2/30 [typing-extensions]
#   Attempting uninstall: triton━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/30 [typing-extensions]
#     Found existing installation: triton 3.5.1━━━━━━━━━━━━━━━━━  2/30 [typing-extensions]
#     Uninstalling triton-3.5.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/30 [typing-extensions]
#       Successfully uninstalled triton-3.5.1━━━━━━━━━━━━━━━━━━━  2/30 [typing-extensions]
#   Attempting uninstall: sympy0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/30 [triton]nsions]
#     Found existing installation: sympy 1.14.0━━━━━━━━━━━━━━━━━━━━━  4/30 [sympy]
#     Uninstalling sympy-1.14.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/30 [sympy]
#       Successfully uninstalled sympy-1.14.0━━━━━━━━━━━━━━━━━━━━━━━  4/30 [sympy]
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/30 [sympy]
#     Found existing installation: setuptools 80.9.0━━━━━━━━━━━━  4/30 [sympy]
#     Uninstalling setuptools-80.9.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/30 [sympy]
#       Successfully uninstalled setuptools-80.9.0━━━━━━━━━━━━━━━━━━  5/30 [setuptools]
#   Attempting uninstall: pillow90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/30 [setuptools]
#     Found existing installation: pillow 11.3.0━━━━━━━━━━━━━━━━  5/30 [setuptools]
#     Uninstalling pillow-11.3.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/30 [setuptools]
#       Successfully uninstalled pillow-11.3.0━━━━━━━━━━━━━━━━━━  5/30 [setuptools]
#   Attempting uninstall: nvidia-nvtx-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  6/30 [pillow]
#     Found existing installation: nvidia-nvtx-cu12 12.8.90━━━━━  6/30 [pillow]
#     Uninstalling nvidia-nvtx-cu12-12.8.90:━━━━━━━━━━━━━━━━━━━━  6/30 [pillow]
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90━━━━━━━━━━━  7/30 [nvidia-nvtx-cu12]
#   Attempting uninstall: nvidia-nvshmem-cu12━━━━━━━━━━━━━━━━━━━  7/30 [nvidia-nvtx-cu12]
#     Found existing installation: nvidia-nvshmem-cu12 3.3.20━━━  7/30 [nvidia-nvtx-cu12]
#     Uninstalling nvidia-nvshmem-cu12-3.3.20:━━━━━━━━━━━━━━━━━━  7/30 [nvidia-nvtx-cu12]
#       Successfully uninstalled nvidia-nvshmem-cu12-3.3.20━━━━━  7/30 [nvidia-nvtx-cu12]
#   Attempting uninstall: nvidia-nvjitlink-cu12━━━━━━━━━━━━━━━━━━━━━  8/30 [nvidia-nvshmem-cu12]
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93  8/30 [nvidia-nvshmem-cu12]
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:━━━━━━━━━━━━━━━  8/30 [nvidia-nvshmem-cu12]
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93━━  8/30 [nvidia-nvshmem-cu12]
#   Attempting uninstall: nvidia-nccl-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  9/30 [nvidia-nvjitlink-cu12]
#     Found existing installation: nvidia-nccl-cu12 2.27.5━━━━━━  9/30 [nvidia-nvjitlink-cu12]
#     Uninstalling nvidia-nccl-cu12-2.27.5:━━━━━━━━━━━━━━━━━━━━━  9/30 [nvidia-nvjitlink-cu12]
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5━━━━━━━━  9/30 [nvidia-nvjitlink-cu12]
#   Attempting uninstall: nvidia-curand-cu12━━━━━━━━━━━━━━━━━━━━━━━━ 10/30 [nvidia-nccl-cu12]]
#     Found existing installation: nvidia-curand-cu12 10.3.9.90━ 10/30 [nvidia-nccl-cu12]
#     Uninstalling nvidia-curand-cu12-10.3.9.90:━━━━━━━━━━━━━━━━ 10/30 [nvidia-nccl-cu12]
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90━━━━━━━ 11/30 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cufile-cu12━━━━━━━━━━━━━━━━━━━━━━━━ 11/30 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cufile-cu12 1.13.1.3━━ 11/30 [nvidia-curand-cu12]
#     Uninstalling nvidia-cufile-cu12-1.13.1.3:━━━━━━━━━━━━━━━━━ 11/30 [nvidia-curand-cu12]
#       Successfully uninstalled nvidia-cufile-cu12-1.13.1.3━━━━ 11/30 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cuda-runtime-cu12━━━━━━━━━━━━━━━━━━ 12/30 [nvidia-cufile-cu12]
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90m 12/30 [nvidia-cufile-cu12]
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:━━━━━━━━━━━━ 12/30 [nvidia-cufile-cu12]
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90 12/30 [nvidia-cufile-cu12]
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12━━━━━━━━━━━━━━━━ 12/30 [nvidia-cufile-cu12]
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93 12/30 [nvidia-cufile-cu12]
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:━━━━━━━━━━━━━━ 12/30 [nvidia-cufile-cu12]
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93━ 12/30 [nvidia-cufile-cu12]
#   Attempting uninstall: nvidia-cuda-cupti-cu12━━━━━━━━━━━━━━━━━━━━ 14/30 [nvidia-cuda-nvrtc-cu12]
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90 14/30 [nvidia-cuda-nvrtc-cu12]
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:━━━━━━━━━━━━━━ 14/30 [nvidia-cuda-nvrtc-cu12]
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90━ 14/30 [nvidia-cuda-nvrtc-cu12]
#   Attempting uninstall: nvidia-cublas-cu12━━━━━━━━━━━━━━━━━━━ 15/30 [nvidia-cuda-cupti-cu12]
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1━━ 15/30 [nvidia-cuda-cupti-cu12]
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:━━━━━━━━━━━━━━━━━ 15/30 [nvidia-cuda-cupti-cu12]
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1━━━━ 15/30 [nvidia-cuda-cupti-cu12]
#   Attempting uninstall: numpy╺━━━━━━━━━━━━━━━━━━ 16/30 [nvidia-cublas-cu12]
#     Found existing installation: numpy 2.2.6━━━━━━━━━━━━━━━━━━ 16/30 [nvidia-cublas-cu12]
#     Uninstalling numpy-2.2.6:╺━━━━━━━━━━━━━━━━━━ 16/30 [nvidia-cublas-cu12]
#       Successfully uninstalled numpy-2.2.60m━━━━━━━━━━━━━━━━━━ 16/30 [nvidia-cublas-cu12]
#   Attempting uninstall: networkx0m╸━━━━━━━━━━━━━━━━━ 17/30 [numpy]las-cu12]
#     Found existing installation: networkx 3.5━━━━━━━━━━━━━━━━━ 17/30 [numpy]
#     Uninstalling networkx-3.5:━━╺━━━━━━━━━━━━━━━ 18/30 [networkx]
#       Successfully uninstalled networkx-3.5━━━━━━━━━━━━━━━ 18/30 [networkx]
#   Attempting uninstall: MarkupSafe0m╺━━━━━━━━━━━━━━━ 18/30 [networkx]
#     Found existing installation: MarkupSafe 3.0.3━━━━━━━━━━━━━ 18/30 [networkx]
#     Uninstalling MarkupSafe-3.0.3:90m╺━━━━━━━━━━━━━━━ 18/30 [networkx]
#       Successfully uninstalled MarkupSafe-3.0.3━━━━━━━━━━━━━━━ 18/30 [networkx]
#   Attempting uninstall: fsspec0m╺━━━━━━━━━━━━━━━ 18/30 [networkx]
#     Found existing installation: fsspec 2024.12.0━━━━━━━━━━━━━ 20/30 [fsspec]
#     Uninstalling fsspec-2024.12.0:╸━━━━━━━━━━━━━ 20/30 [fsspec]
#       Successfully uninstalled fsspec-2024.12.00m━━━━━━━━━━━━━ 20/30 [fsspec]
#   Attempting uninstall: filelock0m╸━━━━━━━━━━━━━ 20/30 [fsspec]
#     Found existing installation: filelock 3.20.00m━━━━━━━━━━━ 21/30 [filelock]
#     Uninstalling filelock-3.20.0:╺━━━━━━━━━━━ 21/30 [filelock]
#       Successfully uninstalled filelock-3.20.0━━━━━━━━━━━ 21/30 [filelock]
#   Attempting uninstall: nvidia-cusparse-cu120m━━━━━━━━━━━ 21/30 [filelock]
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93 21/30 [filelock]
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:90m━━━━━━━━━━━ 21/30 [filelock]
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93━ 21/30 [filelock]
#   Attempting uninstall: nvidia-cufft-cu12╺━━━━━━━━━━ 22/30 [nvidia-cusparse-cu12]
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83━━ 22/30 [nvidia-cusparse-cu12]
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:0m━━━━━━━━━━ 22/30 [nvidia-cusparse-cu12]
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83━━━━ 22/30 [nvidia-cusparse-cu12]
#   Attempting uninstall: nvidia-cudnn-cu12m╸━━━━━━━━━ 23/30 [nvidia-cufft-cu12]
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21━━ 23/30 [nvidia-cufft-cu12]
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:━━━━━━━━━ 23/30 [nvidia-cufft-cu12]
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21━━━━ 23/30 [nvidia-cufft-cu12]
#   Attempting uninstall: jinja2━━━━━━━━━━╺━━━━━━━ 24/30 [nvidia-cudnn-cu12]
#     Found existing installation: Jinja2 3.1.6╺━━━━━━ 25/30 [jinja2]n-cu12]
#     Uninstalling Jinja2-3.1.6:━━━━━━━╺━━━━━━ 25/30 [jinja2]
#       Successfully uninstalled Jinja2-3.1.690m╺━━━━━━ 25/30 [jinja2]
#   Attempting uninstall: nvidia-cusolver-cu120m╺━━━━━━ 25/30 [jinja2]
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90 25/30 [jinja2]
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:━━━━━━ 25/30 [jinja2]
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90━ 25/30 [jinja2]
#   Attempting uninstall: torch━━━━━━━━━━━━━╸━━━━━ 26/30 [nvidia-cusolver-cu12]
#     Found existing installation: torch 2.9.1╺━━━ 27/30 [torch]olver-cu12]
#     Uninstalling torch-2.9.1:━━━━━━━━━━━━━━━╺━━━ 27/30 [torch]
#       Successfully uninstalled torch-2.9.1━━╺━━━ 27/30 [torch]
#   Attempting uninstall: torchvision━━━━━━━━━╺━━━ 27/30 [torch]
#     Found existing installation: torchvision 0.21.0━━━ 27/30 [torch]
#     Uninstalling torchvision-0.21.0:━━━━╺━━━ 27/30 [torch]
#       Successfully uninstalled torchvision-0.21.0╺━━━ 27/30 [torch]
#   Attempting uninstall: torchaudio━━━━━━━━━━━╺━━ 28/30 [torchvision]
#     Found existing installation: torchaudio 2.9.1m╺━━ 28/30 [torchvision]
#     Uninstalling torchaudio-2.9.1:━━━━━━━╺━━ 28/30 [torchvision]
#       Successfully uninstalled torchaudio-2.9.190m╺━━ 28/30 [torchvision]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [torchaudio]0 [torchaudio]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.8 requires onnxruntime<2,>=1.15.0, which is not installed.
# autogluon-multimodal 1.4.0 requires nvidia-ml-py3<8.0,>=7.352.0, which is not installed.
# dash 2.18.1 requires dash-core-components==2.0.0, which is not installed.
# dash 2.18.1 requires dash-html-components==2.0.0, which is not installed.
# dash 2.18.1 requires dash-table==5.0.0, which is not installed.
# jupyter-ai 2.31.6 requires faiss-cpu!=1.8.0.post0,<2.0.0,>=1.8.0, which is not installed.
# sagemaker-studio 1.1.1 requires pydynamodb>=0.7.4, which is not installed.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.8 requires numpy<=2.0.1, but you have numpy 2.4.0 which is incompatible.
# amazon-sagemaker-sql-magic 0.1.4 requires numpy<2, but you have numpy 2.4.0 which is incompatible.
# autogluon-common 1.4.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.0 which is incompatible.
# autogluon-core 1.4.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.0 which is incompatible.
# autogluon-features 1.4.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.0 which is incompatible.
# autogluon-multimodal 1.4.0 requires fsspec[http]<=2025.3, but you have fsspec 2025.12.0 which is incompatible.
# autogluon-multimodal 1.4.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.0 which is incompatible.
# autogluon-multimodal 1.4.0 requires Pillow<12,>=10.0.1, but you have pillow 12.1.0 which is incompatible.
# autogluon-multimodal 1.4.0 requires torch<2.8,>=2.2, but you have torch 2.9.1 which is incompatible.
# autogluon-multimodal 1.4.0 requires torchvision<0.23.0,>=0.16.0, but you have torchvision 0.24.1 which is incompatible.
# autogluon-multimodal 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.57.1 which is incompatible.
# autogluon-tabular 1.4.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.0 which is incompatible.
# autogluon-timeseries 1.4.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.0 which is incompatible.
# autogluon-timeseries 1.4.0 requires torch<2.8,>=2.2, but you have torch 2.9.1 which is incompatible.
# autogluon-timeseries 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.57.1 which is incompatible.
# dash 2.18.1 requires Flask<3.1,>=1.0.4, but you have flask 3.1.2 which is incompatible.
# dash 2.18.1 requires Werkzeug<3.1, but you have werkzeug 3.1.3 which is incompatible.
# gluonts 0.16.2 requires numpy<2.2,>=1.16, but you have numpy 2.4.0 which is incompatible.
# jupyter-scheduler 2.11.0 requires fsspec!=2025.3.1,<=2025.3.2,>=2023.6.0, but you have fsspec 2025.12.0 which is incompatible.
# langchain-aws 0.2.19 requires boto3>=1.37.24, but you have boto3 1.37.3 which is incompatible.
# numba 0.62.1 requires numpy<2.4,>=1.22, but you have numpy 2.4.0 which is incompatible.
# s3fs 2024.12.0 requires fsspec==2024.12.0.*, but you have fsspec 2025.12.0 which is incompatible.
# sagemaker 2.245.0 requires numpy==1.26.4, but you have numpy 2.4.0 which is incompatible.
# sagemaker-studio-analytics-extension 0.2.2 requires sparkmagic==0.22.0, but you have sparkmagic 0.21.0 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.3.3 which is incompatible.
# strands-agents-tools 0.1.9 requires pillow<12.0.0,>=11.2.1, but you have pillow 12.1.0 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.0 which is incompatible.
# sagemaker-studio 1.1.1 requires numpy<2.3.0,>=1.26.4, but you have numpy 2.4.0 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 filelock-3.20.2 fsspec-2025.12.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.0 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 pillow-12.1.0 setuptools-80.9.0 sympy-1.14.0 torch-2.9.1 torchaudio-2.9.1 torchvision-0.24.1 triton-3.5.1 typing-extensions-4.15.0

# %%
# Dependency Check Here
# opencv-python Missing is OK Only for GUI

import importlib

libs_to_check = [
    # Hugging Face core
    "torch", "torchvision", "torchaudio",
    "transformers", "diffusers", "accelerate",

    # Memory/optimization
    "xformers", "bitsandbytes", "safetensors", "einops",

    # Training frameworks
    "pytorch_lightning", "prodigyopt", "lion_pytorch",

    # Data & preprocessing
    "opencv-python", "cv2", "PIL", "ftfy", "sentencepiece", "datasets",

    # Utils & viz
    "tensorboard", "huggingface_hub", "altair", "easygui",
    "toml", "voluptuous", "imagesize", "rich"
]

# special cases where version attribute differs
special_version_attrs = {
    "cv2": "version",
    "PIL": "PILLOW_VERSION",  # old
}

for lib in libs_to_check:
    try:
        module_name = lib.replace("-", "_")
        module = importlib.import_module(module_name)

        # try __version__, or special attributes, or unknown
        version = getattr(module, "__version__", None)
        if version is None:
            # handle cv2, PIL, etc.
            if lib in special_version_attrs:
                version = getattr(module, special_version_attrs[lib], None)
            elif lib == "PIL":
                try:
                    import PIL
                    version = getattr(PIL, "__version__", None)
                except Exception:
                    version = None

        print(f"✅ {lib} - {version if version else 'unknown'}")

    except Exception as e:
        print(f"❌ {lib} - MISSING ({e.__class__.__name__})")
# Out:
# ✅ torch - 2.9.1+cu128
# ✅ torchvision - 0.24.1+cu128
# ✅ torchaudio - 2.9.1+cu128
# ✅ transformers - 4.57.1
# ✅ diffusers - 0.36.0
# ✅ accelerate - 1.11.0
# ✅ xformers - 0.0.33.post2
# ✅ bitsandbytes - 0.49.0
# ✅ safetensors - 0.6.2
# ✅ einops - 0.8.1
# ✅ pytorch_lightning - 2.5.5
# ✅ prodigyopt - unknown
# ✅ lion_pytorch - unknown
# ❌ opencv-python - MISSING (ModuleNotFoundError)
# ✅ cv2 - 4.12.0
# ✅ PIL - 12.1.0
# ✅ ftfy - 6.3.1
# ✅ sentencepiece - 0.2.0
# ✅ datasets - 2.2.1
# ✅ tensorboard - 2.18.0
# ✅ huggingface_hub - 0.36.0
# ✅ altair - 5.5.0
# ✅ easygui - unknown
# ✅ toml - 0.10.2
# ✅ voluptuous - 0.16.0
# ✅ imagesize - 1.4.1
# ✅ rich - unknown

# %% [markdown]
# ## STEP 2 — Download Base Model

# %%
from huggingface_hub import snapshot_download, login

# 🔑 Login with your HuggingFace token (must have accepted SDXL license)
login("")
MODEL = "sdxl-base-1.0"
MODEL_DIR = f"./content/{MODEL}" # Set our Path to Drive If needed

# 📥 Download SDXL 1.0 base model from StabilityAI

snapshot_download(
    repo_id="stabilityai/stable-diffusion-xl-base-1.0",
    local_dir=MODEL_DIR,
    local_dir_use_symlinks=False,
    allow_patterns=[
        "*.safetensors",              # main weights
        "model_index.json",           # model config
        "tokenizer/*",
        "tokenizer/*", "tokenizer_2/*",   # << include both!
        "text_encoder/*", "text_encoder_2/*",# tokenizer files
        "scheduler/*",                # schedulers
        "vae/*",                      # VAE
        "unet/*",                     # UNet
        "text_encoder/*",             # text encoder
        "*.json",                     # other configs
    ]
)

print("✅ SDXL 1.0 Base download complete at /content/sdxl-base-1.0")
# Out:
# /opt/conda/lib/python3.12/site-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 45 files:   0%|          | 0/45 [00:00<?, ?it/s]
# ✅ SDXL 1.0 Base download complete at /content/drive/MyDrive/SD/models/sdxl-base-1.0

# %% [markdown]
# ## STEP 3 — Project Config
#
# In this step, we set up the project details and training parameters:
#
# - **Project Name** — used to create folders for datasets, outputs, and logs.
# - **Trigger Word** — a unique token (e.g., `akashawriter`) that activates your LoRA.
# - **Paths** — dataset, images, outputs, and logs are auto-created in Google Drive.

# %%
# ==== USER CONFIG ====
PROJECT_NAME = "SDXLORA"
TRIGGER      = "SDXLORA"

# Paths
DATASET_DIR  = f"./content/{PROJECT_NAME}/"
IMAGES_DIR   = f"./content/{PROJECT_NAME}/5_{TRIGGER}/"
OUTPUT_DIR   = f"./content/lora/LoRA_Output/{PROJECT_NAME}"
LOG_DIR      = f"./content/lora/LoRA_Logs/{PROJECT_NAME}"

# Create folders if not exist
import os
for p in [DATASET_DIR, OUTPUT_DIR, LOG_DIR, IMAGES_DIR]:
    os.makedirs(p, exist_ok=True)

print("✅ Folders ready:")
print("📂 Dataset Dir :", DATASET_DIR)
print("📂 Images Dir  :", IMAGES_DIR)
print("📂 Output Dir  :", OUTPUT_DIR)
print("📂 Log Dir     :", LOG_DIR)
print("\n⚡ Place your training images inside:", IMAGES_DIR)
# Out:
# ✅ Folders ready:
# 📂 Dataset Dir : ./content/SDXLORA/
# 📂 Images Dir  : ./content/SDXLORA/5_SDXLORA/
# 📂 Output Dir  : ./content/lora/LoRA_Output/SDXLORA
# 📂 Log Dir     : ./content/lora/LoRA_Logs/SDXLORA
#
# ⚡ Place your training images inside: ./content/SDXLORA/5_SDXLORA/

# %% [markdown]
# ## STEP 4 — Upload Images ( You Can Skip This If you Have DataSet Ready )
# ### Copy images into the dataset folder directly:
# - Put all images into: `LoRA_Datasets/5_<PROJECT_NAME>`

# %%
# Optional - Converts Image to Single Format & Trims the photo

import os
from PIL import Image
import cv2

# Path where your images are stored
# IMAGES_DIR = "/content/drive/MyDrive/LoRA_Datasets/Vidya_Balan/10_Vidya_Balan"

TARGET_SIZE = 1024 # Chnage this as Required
count = 0

for fname in os.listdir(IMAGES_DIR):
    fpath = os.path.join(IMAGES_DIR, fname)

    # Skip non-image files
    if not fname.lower().endswith(('.jpg', '.jpeg', '.png', '.webp', '.avif')):
        continue

    try:
        # Load image with cv2 (handles webp/avif better than PIL directly)
        img = cv2.imread(fpath, cv2.IMREAD_UNCHANGED)
        if img is None:
            print(f"⚠️ Skipped (not an image): {fname}")
            continue

        # Convert to RGB
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        pil_img = Image.fromarray(img)

        # --- Center crop (square) ---
        w, h = pil_img.size
        min_dim = min(w, h)
        left = (w - min_dim) // 2
        top = (h - min_dim) // 2
        right = left + min_dim
        bottom = top + min_dim
        pil_img = pil_img.crop((left, top, right, bottom))

        # --- Resize ---
        pil_img = pil_img.resize((TARGET_SIZE, TARGET_SIZE), Image.LANCZOS)

        # --- Save as JPG with clean name ---
        clean_name = f"vidya_{count:03d}.jpg"
        save_path = os.path.join(IMAGES_DIR, clean_name)
        pil_img.save(save_path, "JPEG", quality=95)

        # --- Delete the old file (only if name is different from the new one) ---
        if fpath != save_path:
            os.remove(fpath)

        count += 1

    except Exception as e:
        print(f"❌ Error on {fname}: {e}")

print(f"✅ Processed {count} images. Only clean JPG files remain in {IMAGES_DIR}")
# Out:
# ✅ Processed 10 images. Only clean JPG files remain in ./content/SDXLORA/5_SDXLORA/

# %% [markdown]
# ## STEP 5 — (Optional) Auto‑Generate Simple Captions
# Optional but Highly Reccomeded
#
# This creates a **.txt** file next to each image using your template. You can edit them later. For higher quality, you should hand‑write short, accurate captions per image.

# %%
import glob, os

# Base caption template used for auto-captioning (optional). Keep it SIMPLE.
# Adjust for your Images
CAPTION_TEMPLATE = f"photo of {TRIGGER} with sun glasses, professional photo, high quality, detailed face, studio lighting, white background wall"

print("After creating caption files, add the actual captions for accurate results. (Reccomended)")
image_exts = (".png", ".jpg", ".jpeg", ".webp", ".bmp")

imgs = [p for p in glob.glob(os.path.join(DATASET_DIR, "**/*"), recursive=True) if os.path.splitext(p)[1].lower() in image_exts]
print(f"Found {len(imgs)} images")

for img_path in imgs:
    base, _ = os.path.splitext(img_path)
    txt_path = base + ".txt"
    if not os.path.exists(txt_path):
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write(CAPTION_TEMPLATE)

print("Caption files created where missing.")
# Out:
# After creating caption files, add the actual captions for accurate results. (Reccomended)
# Found 10 images
# Caption files created where missing.

# %% [markdown]
# ## STEP 6 — Train LoRA (kohya-ss `sdxl_train_network.py`)
# **Tips:**
# - Start with the defaults. If results look samey/overfit, reduce `MAX_STEPS` or improve dataset.
# - If underfit (not learning your subject), **increase** `MAX_STEPS` to 6–8k or improve captions.
# - Keep `NETWORK_DIM` at 16/32 for small, flexible LoRAs.
#
# - **Resolution** — choose `512` (faster, lighter) or `768` (more detail, higher VRAM).
# - **Batch Size** — set to `1` (use `2` if GPU has enough VRAM).
# - **Max Steps** — training iterations (start with 3k–5k, adjust based on results).
# - **Network Dim / Alpha** — controls LoRA size & capacity (16–32 is common).
# - **Learning Rates** — fine-tuned for text encoder and U-Net.
#
# 👉 If you’re unsure, keep the defaults — they work well for most cases.

# %%
import os

# ----------------------
# CONFIG
# ----------------------
PRETRAINED_MODEL = "stabilityai/stable-diffusion-xl-base-1.0"
# MODEL_DIR

# Hyperparameters tuned for A100/L4
RESOLUTION        = 512          # 768 or lesser is safe for Weaker GPU
BATCH_SIZE        = 1             # Chnage it according to power
GRAD_ACC_STEPS    = 2             # Chnage it according to power
MAX_STEPS         = 150
NETWORK_DIM       = 64
NETWORK_ALPHA     = 32
LEARNING_RATE     = 1.0            # Prodigy expects ~1.0, not 1e-4

# ----------------------
# TRAINING COMMAND
# ----------------------

train_cmd = f'''
accelerate launch --mixed_precision=fp16 ./content/sdxl_train_network.py \
  --pretrained_model_name_or_path="{PRETRAINED_MODEL}" \
  --train_data_dir="{DATASET_DIR}" \
  --output_dir="{OUTPUT_DIR}" \
  --logging_dir="{LOG_DIR}" \
  --resolution={RESOLUTION} \
  --network_module=networks.lora \
  --network_dim={NETWORK_DIM} \
  --network_alpha={NETWORK_ALPHA} \
  --learning_rate={LEARNING_RATE} \
  --train_batch_size={BATCH_SIZE} \
  --gradient_accumulation_steps={GRAD_ACC_STEPS} \
  --max_train_steps={MAX_STEPS} \
  --save_every_n_steps=500 \
  --save_last_n_steps=3 \
  --save_last_n_epochs=3 \
  --save_state \
  --save_precision=fp16 \
  --optimizer_type=Prodigy \
  --mem_eff_attn \
  --shuffle_caption \
  --caption_extension=.txt \
  --max_data_loader_n_workers=2 \
  --log_prefix="female_writer_v1" \
  --enable_bucket \
  --bucket_reso_steps=64 \
  --random_crop \
  --log_with tensorboard \
  2>&1 | tee ./content/train.log
'''

# ----------------------
# RUN TRAINING
# ----------------------
print("🚀 Starting LoRA training...\n")
exit_code = os.system(train_cmd)
print("\n✅ Training finished with exit code:", exit_code)
# Out:
# 🚀 Starting LoRA training...
#
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2026-01-08 14:36:57.194774: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767883017.223355    3113 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767883017.235041    3113 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-08 14:36:57.336831: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-08 14:37:06 INFO     prepare tokenizers           ]8;id=983192;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py\sdxl_train_util.py]8;;\:]8;id=375557;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py#138\138]8;;\
# 2026-01-08 14:37:07 INFO     Using DreamBooth method.       ]8;id=710295;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py\train_network.py]8;;\:]8;id=228840;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py#172\172]8;;\
#                     INFO     prepare images.                  ]8;id=340039;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=823218;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#1689\1689]8;;\
#                     INFO     found directory                  ]8;id=742215;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=344216;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#1636\1636]8;;\
#                              content/SDXLORA/5_SDXLORA
#                              contains 10 image files
#                     INFO     50 train images with repeating.  ]8;id=441767;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=871038;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#1730\1730]8;;\
#                     INFO     0 reg images.                    ]8;id=905412;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=817378;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#1733\1733]8;;\
#                     WARNING  no regularization images /       ]8;id=219114;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=553749;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#1738\1738]8;;\
#                              正則化画像が見つかりませんでした
#                     INFO     [Dataset 0]                      ]8;id=13552;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/config_util.py\config_util.py]8;;\:]8;id=637924;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/config_util.py#572\572]8;;\
#                                batch_size: 1
#                                resolution: (512, 512)
#                                enable_bucket: True
#                                network_multiplier: 1.0
#                                min_bucket_reso: 256
#                                max_bucket_reso: 1024
#                                bucket_reso_steps: 64
#                                bucket_no_upscale: False
#
#                                [Subset 0 of Dataset 0]
#                                  image_dir:
#                              "content/SDXLORA/5_SDXLORA"
#                                  image_count: 10
#                                  num_repeats: 5
#                                  shuffle_caption: True
#                                  keep_tokens: 0
#                                  keep_tokens_separator:
#                                  caption_separator: ,
#                                  secondary_separator: None
#                                  enable_wildcard: False
#                                  caption_dropout_rate: 0.0
#                                  caption_dropout_every_n_epoc
#                              hes: 0
#                                  caption_tag_dropout_rate:
#                              0.0
#                                  caption_prefix: None
#                                  caption_suffix: None
#                                  color_aug: False
#                                  flip_aug: False
#                                  face_crop_aug_range: None
#                                  random_crop: True
#                                  token_warmup_min: 1,
#                                  token_warmup_step: 0,
#                                  alpha_mask: False,
#                                  is_reg: False
#                                  class_tokens: SDXLORA
#                                  caption_extension: .txt
#
#
#                     INFO     [Dataset 0]                      ]8;id=988550;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/config_util.py\config_util.py]8;;\:]8;id=359992;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/config_util.py#578\578]8;;\
#                     INFO     loading image sizes.              ]8;id=604087;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=225575;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#901\901]8;;\
# 100%|██████████| 10/10 [00:00<00:00, 1673.30it/s]
#                     INFO     make buckets                      ]8;id=530247;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=766697;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#907\907]8;;\
#                     INFO     number of images (including       ]8;id=896260;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=443447;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#953\953]8;;\
#                              repeats) /
#                              各bucketの画像枚数（繰り返し回数
#                              を含む）
#                     INFO     bucket 0: resolution (512, 512),  ]8;id=407317;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=313592;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#958\958]8;;\
#                              count: 50
#                     INFO     mean ar error (without repeats):  ]8;id=447036;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=273837;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#966\966]8;;\
#                              0.0
#                     INFO     preparing accelerator          ]8;id=136550;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py\train_network.py]8;;\:]8;id=919360;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py#225\225]8;;\
#                     INFO     loading model for process 0/1 ]8;id=941802;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py\sdxl_train_util.py]8;;\:]8;id=733293;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py#33\33]8;;\
#                     INFO     load Diffusers pretrained     ]8;id=878565;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py\sdxl_train_util.py]8;;\:]8;id=739543;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py#88\88]8;;\
#                              models:
#                              stabilityai/stable-diffusion-
#                              xl-base-1.0, variant=None
# accelerator device: cuda
# Loading pipeline components...: 100%|██████████| 6/6 [00:02<00:00,  2.06it/s]
# 2026-01-08 14:37:10 INFO     U-Net converted to original  ]8;id=890750;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py\sdxl_train_util.py]8;;\:]8;id=225654;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/sdxl_train_util.py#124\124]8;;\
#                              U-Net
# 2026-01-08 14:37:11 INFO     Enable memory efficient          ]8;id=439797;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=607854;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#2832\2832]8;;\
#                              attention for U-Net
# 2026-01-08 14:37:35 INFO     create LoRA network. base dim (rank):   ]8;id=961482;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=831861;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#935\935]8;;\
#                              64, alpha: 32.0
#                     INFO     neuron dropout: p=None, rank dropout:   ]8;id=510073;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=615592;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#936\936]8;;\
#                              p=None, module dropout: p=None
#                     INFO     create LoRA for Text Encoder 1:        ]8;id=16996;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=767022;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#1027\1027]8;;\
#                     INFO     create LoRA for Text Encoder 2:        ]8;id=390133;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=833180;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#1027\1027]8;;\
#                     INFO     create LoRA for Text Encoder: 264      ]8;id=105494;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=821159;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#1035\1035]8;;\
#                              modules.
# 2026-01-08 14:37:37 INFO     create LoRA for U-Net: 722 modules.    ]8;id=856812;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=601742;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#1043\1043]8;;\
#                     INFO     enable LoRA for text encoder: 264      ]8;id=713649;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=77591;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#1084\1084]8;;\
#                              modules
#                     INFO     enable LoRA for U-Net: 722 modules     ]8;id=870408;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py\lora.py]8;;\:]8;id=603930;file:///home/sagemaker-user/Text-to-Image-Generator/content/networks/lora.py#1089\1089]8;;\
#                     INFO     use Prodigy optimizer | {}       ]8;id=121683;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=38159;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#4315\4315]8;;\
# import network module: networks.lora
# prepare optimizer, data loader etc.
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 50
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 50
#   num epochs / epoch数: 6
#   batch size per device / バッチサイズ: 1
#   gradient accumulation steps / 勾配を合計するステップ数 = 2
#   total optimization steps / 学習ステップ数: 150
# steps:   0%|          | 0/150 [00:00<?, ?it/s]
# epoch 1/6
# 2026-01-08 14:38:56 INFO     epoch is incremented.             ]8;id=672093;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=159732;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 1
# 2026-01-08 14:38:56 INFO     epoch is incremented.             ]8;id=347578;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=512731;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 1
# steps:  17%|█▋        | 25/150 [00:59<04:58,  2.39s/it, avr_loss=0.12]
# epoch 2/6
# 2026-01-08 14:39:56 INFO     epoch is incremented.             ]8;id=89328;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=747145;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 2
# 2026-01-08 14:39:56 INFO     epoch is incremented.             ]8;id=576943;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=518309;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 2
# steps:  33%|███▎      | 50/150 [01:57<03:54,  2.35s/it, avr_loss=0.0974]
# epoch 3/6
# 2026-01-08 14:40:54 INFO     epoch is incremented.             ]8;id=706676;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=296207;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 3
# 2026-01-08 14:40:54 INFO     epoch is incremented.             ]8;id=851404;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=28195;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 3
# steps:  50%|█████     | 75/150 [02:54<02:54,  2.33s/it, avr_loss=0.116]
# epoch 4/6
# 2026-01-08 14:41:51 INFO     epoch is incremented.             ]8;id=302420;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=710922;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 4
# 2026-01-08 14:41:51 INFO     epoch is incremented.             ]8;id=427784;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=18343;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 4
# steps:  67%|██████▋   | 100/150 [03:51<01:55,  2.32s/it, avr_loss=0.107]
# epoch 5/6
# 2026-01-08 14:42:48 INFO     epoch is incremented.             ]8;id=899714;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=528237;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 5
# 2026-01-08 14:42:48 INFO     epoch is incremented.             ]8;id=979535;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=6972;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 5
# steps:  83%|████████▎ | 125/150 [04:49<00:57,  2.32s/it, avr_loss=0.114]
# epoch 6/6
# 2026-01-08 14:43:46 INFO     epoch is incremented.             ]8;id=732984;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=620453;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 6
# 2026-01-08 14:43:46 INFO     epoch is incremented.             ]8;id=615345;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=85470;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#693\693]8;;\
#                              current_epoch: 0, epoch: 6
# steps: 100%|██████████| 150/150 [05:49<00:00,  2.33s/it, avr_loss=0.0917]2026-01-08 14:44:45 INFO                                      ]8;id=129913;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=502512;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#5128\5128]8;;\
#                     INFO     saving last state.               ]8;id=712347;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py\train_util.py]8;;\:]8;id=23889;file:///home/sagemaker-user/Text-to-Image-Generator/content/library/train_util.py#5129\5129]8;;\
#                     INFO     Saving current state to         ]8;id=73404;file:///opt/conda/lib/python3.12/site-packages/accelerate/accelerator.py\accelerator.py]8;;\:]8;id=231556;file:///opt/conda/lib/python3.12/site-packages/accelerate/accelerator.py#3532\3532]8;;\
#                              ./content/lora/LoRA_Output/SDXL
#                              ORA/last-state
#                     INFO     save train state to            ]8;id=189077;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py\train_network.py]8;;\:]8;id=64007;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py#510\510]8;;\
#                              ./content/lora/LoRA_Output/SDX
#                              LORA/last-state/train_state.js
#                              on at epoch 6 step 150
# 2026-01-08 14:44:47 INFO     Model weights saved in         ]8;id=410282;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py\checkpointing.py]8;;\:]8;id=209039;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py#114\114]8;;\
#                              content/lora/LoRA_Output/SDXLO
#                              RA/last-state/model.safetensor
#                              s
# 2026-01-08 14:44:51 INFO     Optimizer state saved in       ]8;id=879049;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py\checkpointing.py]8;;\:]8;id=946134;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py#121\121]8;;\
#                              content/lora/LoRA_Output/SDXLO
#                              RA/last-state/optimizer.bin
#                     INFO     Scheduler state saved in       ]8;id=213295;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py\checkpointing.py]8;;\:]8;id=804623;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py#128\128]8;;\
#                              content/lora/LoRA_Output/SDXLO
#                              RA/last-state/scheduler.bin
#                     INFO     Sampler state for dataloader 0 ]8;id=169821;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py\checkpointing.py]8;;\:]8;id=358940;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py#145\145]8;;\
#                              saved in
#                              content/lora/LoRA_Output/SDXLO
#                              RA/last-state/sampler.bin
#                     INFO     Random states saved in         ]8;id=463799;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py\checkpointing.py]8;;\:]8;id=697938;file:///opt/conda/lib/python3.12/site-packages/accelerate/checkpointing.py#176\176]8;;\
#                              content/lora/LoRA_Output/SDXLO
#                              RA/last-state/random_states_0.
#                              pkl
# 2026-01-08 14:44:57 INFO     model saved.                  ]8;id=943821;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py\train_network.py]8;;\:]8;id=596757;file:///home/sagemaker-user/Text-to-Image-Generator/content/train_network.py#1112\1112]8;;\
# steps: 100%|██████████| 150/150 [06:01<00:00,  2.41s/it, avr_loss=0.0917]
#
# saving checkpoint: ./content/lora/LoRA_Output/SDXLORA/last.safetensors
#
# ✅ Training finished with exit code: 0

# %% [markdown]
# ## STEP 7 — Test the LoRA
# This loads SD1.5 and your LoRA, only do once.

# %%
import os, glob
import gc
from diffusers import StableDiffusionXLPipeline
import torch

# find latest safetensors in output
lora_files = sorted([p for p in glob.glob(os.path.join(OUTPUT_DIR, "*.safetensors"))], key=os.path.getmtime)
assert lora_files, "No LoRA files found in OUTPUT_DIR. Check training output."
LORA_PATH = lora_files[-1]
print("Using LoRA:", LORA_PATH)

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    dtype=torch.float16,          
    use_safetensors=True,         
).to("cuda")

# Load LoRA
pipe.load_lora_weights(os.path.dirname(LORA_PATH), weight_name=os.path.basename(LORA_PATH))

print("Model is loaded!")
# Out:
# 2026-01-08 14:46:19.548850: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767883579.577942    2985 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767883579.589229    2985 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-08 14:46:19.705710: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using LoRA: ./content/lora/LoRA_Output/SDXLORA/last.safetensors
# Keyword arguments {'dtype': torch.float16} are not expected by StableDiffusionXLPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# ## Use the cell below to generate images.

# %%
RESOLUTION = 1024

prompt = f"Photo of {TRIGGER} driving a car"
neg = "cartoon, anime, illustration, blurry, low quality, bad proportions, deformation watermark, logo, text"

print("Image generation started!")
image = pipe(prompt, negative_prompt=neg, num_inference_steps=30, guidance_scale=7.5, height=RESOLUTION, width=RESOLUTION).images[0]

image.save("sample_lora_output.png")
print("Saved sample_lora_output.png")
display(image)
# Out:
# Image generation started!
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved sample_lora_output.png
# <PIL.Image.Image image mode=RGB size=1024x1024>
