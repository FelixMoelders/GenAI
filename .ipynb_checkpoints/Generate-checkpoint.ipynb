# %%
# !pip install diffusers["torch"]
# Out:
# Collecting diffusers[torch]
#   Using cached diffusers-0.36.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (6.10.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (3.20.0)
# Requirement already satisfied: httpx<1.0.0 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (0.36.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (2025.11.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (0.7.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (11.3.0)
# Requirement already satisfied: torch>=1.4 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (2.6.0)
# Requirement already satisfied: accelerate>=0.31.0 in /opt/conda/lib/python3.12/site-packages (from diffusers[torch]) (1.12.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (4.12.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0->diffusers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->diffusers[torch]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.2.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.15.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from accelerate>=0.31.0->diffusers[torch]) (5.9.8)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (80.9.0)
# Requirement already satisfied: sympy!=1.13.2,>=1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.4->diffusers[torch]) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy!=1.13.2,>=1.13.1->torch>=1.4->diffusers[torch]) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib_metadata->diffusers[torch]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.4->diffusers[torch]) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->diffusers[torch]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->diffusers[torch]) (1.26.20)
# Using cached diffusers-0.36.0-py3-none-any.whl (4.6 MB)
# Installing collected packages: diffusers
# Successfully installed diffusers-0.36.0

# %%
# ============================================================
# TEXT-TO-IMAGE MODEL LOADER
# (RUN THIS CELL ONLY ONCE IN JUPYTER LAB)
# ============================================================

import os
import torch
import warnings
from diffusers import StableDiffusionXLPipeline
import warnings
warnings.filterwarnings('ignore')

# ------------------------------------------------------------
# Suppress unnecessary warnings for clean notebook output
# ------------------------------------------------------------
warnings.filterwarnings("ignore")

# ------------------------------------------------------------
# Device & Precision Configuration
# ------------------------------------------------------------
# - CUDA + float16 → Faster & memory-efficient
# - CPU + float32 → Stable fallback
# ------------------------------------------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float16 if device == "cuda" else torch.float32

print(f" Running on device : {device}")
print(f" Torch data type  : {dtype}")

# ------------------------------------------------------------
# Load SDXL Pipeline from single safetensors file
# ------------------------------------------------------------
pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=dtype,
    add_watermarker=False       # Clean outputs (no watermark)
)

# Move pipeline to selected device (GPU / CPU)
pipe.to(device)

# ------------------------------------------------------------
# Memory Optimization (Important for Jupyter & Low VRAM GPUs)
# ------------------------------------------------------------
pipe.enable_attention_slicing()
pipe.enable_vae_slicing()

print("✅ SDXL model loaded successfully and ready for inference")
# Out:
# 2026-01-09 11:55:31.999200: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767959732.014831     503 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767959732.019699     503 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 11:55:32.036027: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  Running on device : cuda
#  Torch data type  : torch.float16
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# ✅ SDXL model loaded successfully and ready for inference

# %%
# ============================================================
# (RUN THIS CELL TO GENERATE IMAGES FROM TEXT PROMPTS)
# ============================================================

import time
import json
from IPython.display import display

# ------------------------------------------------------------
# Hands on Session I - Bilderzeugung
# Keep prompts concise and descriptive (≈ 70–80 tokens max)
# ------------------------------------------------------------
prompt = 'Iron Man in advanced iron armor Standing on stone, cinematic sunset lighting, dramatic sky, reflective metal surfaces, heroic pose, detailed armor, sharp focus, epic movie scene'

# ------------------------------------------------------------
# Hands on Session II - JSON-Prompt
# Code markieren und Strg + # drücken um code zu aktivieren
# ------------------------------------------------------------
# j_prompt = {
#     "subject": "red sedan",
#     "scene": "country road",
#     "lighting": "dawn",
#     "style": "photorealistic"
# }

# prompt = json.dumps(j_prompt)
# ------------------------------------------------------------


# ------------------------------------------------------------
# NEGATIVE PROMPT
# Helps remove common generation issues
# ------------------------------------------------------------
negative_prompt = 'cartoon, anime, illustration, blurry, low quality, distorted face, extra limbs, extra fingers, deformed armor, bad proportions, watermark, logo, text'

# ------------------------------------------------------------
# GENERATION PARAMETERS (Balanced & Stable Defaults)
# ------------------------------------------------------------
width = 512
height = 512
num_inference_steps = 28     # More steps = better detail (slower)
guidance_scale = 6.5        # Prompt adherence vs creativity
generator = None            # None → more randomness & creativity

# ------------------------------------------------------------
# Inference Execution
# ------------------------------------------------------------
print("Prompt:")
print(prompt)
print("\n Generating image...")

start_time = time.time()

# Disable gradient tracking for faster & memory-safe inference
with torch.no_grad():
    result = pipe(
        prompt=prompt,
        negative_prompt=negative_prompt,
        width=width,
        height=height,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=generator,
    )

# Extract generated image
image = result.images[0]

# Display inside Jupyter Notebook
display(image)

print(f"\n⏱ Generation time: {time.time() - start_time:.1f} seconds")
# Out:
# Prompt:
# Iron Man in advanced iron armor Standing on stone, cinematic sunset lighting, dramatic sky, reflective metal surfaces, heroic pose, detailed armor, sharp focus, epic movie scene
#
#  Generating image...
#   0%|          | 0/28 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# ⏱ Generation time: 4.1 seconds
